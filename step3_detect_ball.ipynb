# %%
# # GoogleDirve の指定したディレクトで作業する場合
# %cd /content/drive/My Drive/project_directory

# %%
# setting
filename = "test_1"
is_save = False

# %% [markdown]
# # step3 : detect ball

# %%
import time
import os
import shutil
import subprocess

# %%
def bgst():
    total_frame = 1001
    down_fps_rate = 1
    down_resolution_rate = 1.0
    
    # ---- bgst ----
    time.sleep(1)
    os.chdir("bgst")

    # flow1. convert movie to images
    print("flow1. convert movie to images")
    # run
    # !python convert_movie2images.py --filename {filename} --total_frame {total_frame} --down_fps_rate {down_fps_rate} --down_resolution_rate {down_resolution_rate}

    # flow2. make mask images
    print("flow2. make mask images")
    # run
    # !python make_mask.py --filename {filename}

    time.sleep(1)
    os.chdir("../")

# %%
def yolo():
    weights = "models_checkpoint/yolov7.pt"
    source = f"../datas/original_images/{filename}"
    project = "../datas/humans_bbox"
    
    # --- yolo ----
    time.sleep(1)
    os.chdir("yolov7")

    # flow3. detect humans bbox
    print('flow3. detect humans bbox')
    # deleate old folder
    save_path = f"../datas/humans_bbox/{filename}"
    if os.path.exists(save_path):
        print('yolo, delete previous folder.')
        shutil.rmtree(save_path)
    else:
        print("yolo, previous folder doesn't exist.")
    # run
    # !python detect.py --save-txt --device 0 --classes 0 --weights {weights} --source {source} --project {project} --name {filename}

    time.sleep(1)
    os.chdir("../")

# %%
def balldet():
    original_fps = 30
    slow_rate = 4
    
    # ---- balldet ----
    time.sleep(1)
    os.chdir("balldet")

    # flow4. make mask2 images
    print("flow4. make mask2 images")
    # run
    # !python make_mask2.py --filename {filename}

    # flow5. detect ball
    print("flow5. detect ball")
    # run
    # !python detect_ball.py --filename {filename}

    # flow6. convert balldet images to movie
    print("flow6. convert balldet images to movie")    
    # run
    # !python convert_images2movie.py --filename {filename} --original_fps {original_fps} --slow_rate {slow_rate}

    time.sleep(1)
    os.chdir("../")

# %%
bgst()
yolo()
balldet()
# Out:
# flow1. convert movie to images
# Namespace(down_fps_rate=1, down_resolution_rate=1.0, filename='test_1', show_viz=None, total_frame=1001)
# 100% 1001/1001 [00:02<00:00, 467.85it/s]
# flow2. make mask images
# Namespace(filename='test_1', show_viz=None)
# 100% 1001/1001 [00:09<00:00, 103.51it/s]
# flow3. detect humans bbox
# yolo, delete previous folder.
# Namespace(agnostic_nms=False, augment=False, classes=[0], conf_thres=0.25, device='0', exist_ok=False, img_size=640, iou_thres=0.45, name='test_1', no_trace=False, nosave=False, project='../datas/humans_bbox', save_conf=False, save_txt=True, source='../datas/original_images/test_1', update=False, view_img=False, weights=['models_checkpoint/yolov7.pt'])
# YOLOR 🚀 cda3b69 torch 1.12.1+cu113 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model Summary: 306 layers, 36905341 parameters, 6652669 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 2 persons, Done. (16.3ms) Inference, (1.5ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame0.bmp
# 2 persons, Done. (16.3ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame1.bmp
# 2 persons, Done. (16.3ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame10.bmp
# 2 persons, Done. (18.1ms) Inference, (1.4ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame100.bmp
# 2 persons, Done. (16.4ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame1000.bmp
# 2 persons, Done. (12.0ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame101.bmp
# 2 persons, Done. (11.8ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame102.bmp
# 2 persons, Done. (11.9ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame103.bmp
# 2 persons, Done. (11.8ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame104.bmp
# 2 persons, Done. (12.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame105.bmp
# 2 persons, Done. (11.8ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame106.bmp
# 2 persons, Done. (11.9ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame107.bmp
# 2 persons, Done. (11.8ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame108.bmp
# 2 persons, Done. (11.9ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame109.bmp
# 2 persons, Done. (11.8ms) Inference, (1.4ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame11.bmp
# 2 persons, Done. (14.3ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame110.bmp
# 2 persons, Done. (11.8ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame111.bmp
# 2 persons, Done. (11.3ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame112.bmp
# 2 persons, Done. (11.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame113.bmp
# 2 persons, Done. (11.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame114.bmp
# 2 persons, Done. (11.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame115.bmp
# 2 persons, Done. (13.7ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame116.bmp
# 2 persons, Done. (11.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame117.bmp
# 2 persons, Done. (11.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame118.bmp
# 2 persons, Done. (10.8ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame119.bmp
# 2 persons, Done. (12.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame12.bmp
# 2 persons, Done. (12.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame120.bmp
# 2 persons, Done. (15.9ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame121.bmp
# 2 persons, Done. (11.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame122.bmp
# 2 persons, Done. (10.9ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame123.bmp
# 2 persons, Done. (11.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame124.bmp
# 2 persons, Done. (11.3ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame125.bmp
# 2 persons, Done. (11.4ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame126.bmp
# 2 persons, Done. (11.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame127.bmp
# 2 persons, Done. (11.4ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame128.bmp
# 2 persons, Done. (11.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame129.bmp
# 2 persons, Done. (11.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame13.bmp
# 2 persons, Done. (11.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame130.bmp
# 2 persons, Done. (11.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame131.bmp
# 2 persons, Done. (11.0ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame132.bmp
# 2 persons, Done. (10.9ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame133.bmp
# 2 persons, Done. (11.4ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame134.bmp
# 2 persons, Done. (11.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame135.bmp
# 2 persons, Done. (12.4ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame136.bmp
# 2 persons, Done. (11.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame137.bmp
# 2 persons, Done. (13.5ms) Inference, (1.3ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame138.bmp
# 2 persons, Done. (11.9ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame139.bmp
# 2 persons, Done. (11.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame14.bmp
# 2 persons, Done. (13.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame140.bmp
# 2 persons, Done. (11.8ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame141.bmp
# 2 persons, Done. (11.4ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame142.bmp
# 2 persons, Done. (13.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame143.bmp
# 2 persons, Done. (11.3ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame144.bmp
# 2 persons, Done. (11.8ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame145.bmp
# 2 persons, Done. (11.4ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame146.bmp
# 2 persons, Done. (11.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame147.bmp
# 2 persons, Done. (12.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame148.bmp
# 2 persons, Done. (11.4ms) Inference, (1.2ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame149.bmp
# 2 persons, Done. (12.3ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame15.bmp
# 2 persons, Done. (11.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame150.bmp
# 2 persons, Done. (12.0ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame151.bmp
# 2 persons, Done. (11.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame152.bmp
# 2 persons, Done. (11.3ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame153.bmp
# 2 persons, Done. (11.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame154.bmp
# 2 persons, Done. (21.8ms) Inference, (1.5ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame155.bmp
# 2 persons, Done. (11.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame156.bmp
# 2 persons, Done. (12.7ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame157.bmp
# 2 persons, Done. (12.3ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame158.bmp
# 2 persons, Done. (12.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame159.bmp
# 2 persons, Done. (12.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame16.bmp
# 2 persons, Done. (10.9ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame160.bmp
# 2 persons, Done. (11.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame161.bmp
# 2 persons, Done. (11.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame162.bmp
# 2 persons, Done. (11.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame163.bmp
# 2 persons, Done. (12.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame164.bmp
# 2 persons, Done. (13.4ms) Inference, (1.3ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame165.bmp
# 2 persons, Done. (11.0ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame166.bmp
# 2 persons, Done. (11.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame167.bmp
# 2 persons, Done. (11.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame168.bmp
# 2 persons, Done. (10.8ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame169.bmp
# 2 persons, Done. (11.9ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame17.bmp
# 2 persons, Done. (11.3ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame170.bmp
# 2 persons, Done. (11.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame171.bmp
# 2 persons, Done. (10.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame172.bmp
# 2 persons, Done. (11.0ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame173.bmp
# 2 persons, Done. (11.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame174.bmp
# 2 persons, Done. (11.9ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame175.bmp
# 2 persons, Done. (11.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame176.bmp
# 2 persons, Done. (11.8ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame177.bmp
# 2 persons, Done. (11.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame178.bmp
# 2 persons, Done. (11.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame179.bmp
# 2 persons, Done. (11.0ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame18.bmp
# 2 persons, Done. (10.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame180.bmp
# 2 persons, Done. (11.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame181.bmp
# 2 persons, Done. (11.6ms) Inference, (1.3ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame182.bmp
# 2 persons, Done. (11.0ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame183.bmp
# 2 persons, Done. (10.8ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame184.bmp
# 2 persons, Done. (10.9ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame185.bmp
# 2 persons, Done. (10.8ms) Inference, (1.5ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame186.bmp
# 2 persons, Done. (14.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame187.bmp
# 2 persons, Done. (11.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame188.bmp
# 2 persons, Done. (11.3ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame189.bmp
# 2 persons, Done. (11.8ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame19.bmp
# 2 persons, Done. (11.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame190.bmp
# 2 persons, Done. (11.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame191.bmp
# 2 persons, Done. (10.8ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame192.bmp
# 2 persons, Done. (11.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame193.bmp
# 2 persons, Done. (11.3ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame194.bmp
# 2 persons, Done. (11.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame195.bmp
# 1 person, Done. (11.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame196.bmp
# 1 person, Done. (11.3ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame197.bmp
# 1 person, Done. (11.4ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame198.bmp
# 1 person, Done. (11.4ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame199.bmp
# 2 persons, Done. (14.3ms) Inference, (1.3ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame2.bmp
# 2 persons, Done. (11.0ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame20.bmp
# 1 person, Done. (10.8ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame200.bmp
# 1 person, Done. (12.4ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame201.bmp
# 1 person, Done. (11.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame202.bmp
# 1 person, Done. (11.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame203.bmp
# 1 person, Done. (19.0ms) Inference, (1.4ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame204.bmp
# 1 person, Done. (21.5ms) Inference, (1.3ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame205.bmp
# 1 person, Done. (17.8ms) Inference, (1.3ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame206.bmp
# 1 person, Done. (23.9ms) Inference, (1.3ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame207.bmp
# 1 person, Done. (12.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame208.bmp
# 1 person, Done. (14.1ms) Inference, (1.3ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame209.bmp
# 2 persons, Done. (14.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame21.bmp
# 1 person, Done. (11.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame210.bmp
# 1 person, Done. (11.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame211.bmp
# 1 person, Done. (11.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame212.bmp
# 1 person, Done. (15.4ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame213.bmp
# 1 person, Done. (11.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame214.bmp
# 1 person, Done. (11.3ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame215.bmp
# 1 person, Done. (11.3ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame216.bmp
# 1 person, Done. (12.9ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame217.bmp
# 1 person, Done. (11.1ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame218.bmp
# 1 person, Done. (12.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame219.bmp
# 2 persons, Done. (11.3ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame22.bmp
# 1 person, Done. (11.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame220.bmp
# 1 person, Done. (11.4ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame221.bmp
# 1 person, Done. (12.8ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame222.bmp
# 1 person, Done. (10.8ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame223.bmp
# 1 person, Done. (14.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame224.bmp
# 1 person, Done. (12.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame225.bmp
# 1 person, Done. (11.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame226.bmp
# 1 person, Done. (10.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame227.bmp
# 1 person, Done. (10.4ms) Inference, (1.2ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame228.bmp
# 1 person, Done. (11.3ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame229.bmp
# 2 persons, Done. (11.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame23.bmp
# 1 person, Done. (10.7ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame230.bmp
# 1 person, Done. (11.3ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame231.bmp
# 1 person, Done. (10.9ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame232.bmp
# 1 person, Done. (13.2ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame233.bmp
# 1 person, Done. (12.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame234.bmp
# 1 person, Done. (11.4ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame235.bmp
# 1 person, Done. (12.9ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame236.bmp
# 1 person, Done. (11.6ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame237.bmp
# 1 person, Done. (10.8ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame238.bmp
# 1 person, Done. (11.1ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame239.bmp
# 2 persons, Done. (11.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame24.bmp
# 1 person, Done. (11.2ms) Inference, (1.3ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame240.bmp
# 1 person, Done. (11.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame241.bmp
# 1 person, Done. (11.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame242.bmp
# 1 person, Done. (11.6ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame243.bmp
# 1 person, Done. (11.8ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame244.bmp
# 1 person, Done. (14.4ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame245.bmp
# 1 person, Done. (11.6ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame246.bmp
# 1 person, Done. (11.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame247.bmp
# 1 person, Done. (11.5ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame248.bmp
# 1 person, Done. (11.3ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame249.bmp
# 2 persons, Done. (11.2ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame25.bmp
# 1 person, Done. (11.4ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame250.bmp
# 1 person, Done. (11.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame251.bmp
# 1 person, Done. (11.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame252.bmp
# 1 person, Done. (14.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame253.bmp
# 1 person, Done. (12.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame254.bmp
# 1 person, Done. (12.3ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame255.bmp
# 1 person, Done. (11.4ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame256.bmp
# 1 person, Done. (13.7ms) Inference, (1.7ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame257.bmp
# 1 person, Done. (11.0ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame258.bmp
# 1 person, Done. (13.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame259.bmp
# 2 persons, Done. (10.8ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame26.bmp
# 1 person, Done. (12.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame260.bmp
# 1 person, Done. (11.4ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame261.bmp
# 1 person, Done. (10.9ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame262.bmp
# 1 person, Done. (11.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame263.bmp
# 1 person, Done. (20.8ms) Inference, (1.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame264.bmp
# 1 person, Done. (16.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame265.bmp
# 1 person, Done. (12.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame266.bmp
# 1 person, Done. (11.3ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame267.bmp
# 1 person, Done. (14.8ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame268.bmp
# 1 person, Done. (11.8ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame269.bmp
# 2 persons, Done. (12.1ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame27.bmp
# 1 person, Done. (11.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame270.bmp
# 1 person, Done. (14.3ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame271.bmp
# 1 person, Done. (15.1ms) Inference, (1.3ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame272.bmp
# 1 person, Done. (16.1ms) Inference, (1.5ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame273.bmp
# 1 person, Done. (13.4ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame274.bmp
# 1 person, Done. (11.9ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame275.bmp
# 1 person, Done. (12.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame276.bmp
# 1 person, Done. (10.9ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame277.bmp
# 1 person, Done. (11.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame278.bmp
# 1 person, Done. (11.3ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame279.bmp
# 2 persons, Done. (10.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame28.bmp
# 1 person, Done. (11.3ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame280.bmp
# 1 person, Done. (10.9ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame281.bmp
# 1 person, Done. (11.0ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame282.bmp
# 1 person, Done. (11.0ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame283.bmp
# 1 person, Done. (13.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame284.bmp
# 1 person, Done. (12.3ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame285.bmp
# 1 person, Done. (10.8ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame286.bmp
# 1 person, Done. (11.4ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame287.bmp
# 1 person, Done. (11.0ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame288.bmp
# 1 person, Done. (11.0ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame289.bmp
# 2 persons, Done. (11.4ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame29.bmp
# 1 person, Done. (11.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame290.bmp
# 1 person, Done. (11.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame291.bmp
# 1 person, Done. (11.3ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame292.bmp
# 1 person, Done. (11.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame293.bmp
# 1 person, Done. (10.9ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame294.bmp
# 1 person, Done. (11.1ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame295.bmp
# 1 person, Done. (10.9ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame296.bmp
# 1 person, Done. (11.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame297.bmp
# 1 person, Done. (11.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame298.bmp
# 1 person, Done. (11.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame299.bmp
# 2 persons, Done. (11.8ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame3.bmp
# 2 persons, Done. (11.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame30.bmp
# 1 person, Done. (15.3ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame300.bmp
# 1 person, Done. (11.7ms) Inference, (1.3ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame301.bmp
# 1 person, Done. (11.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame302.bmp
# 1 person, Done. (11.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame303.bmp
# 1 person, Done. (12.0ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame304.bmp
# 1 person, Done. (11.9ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame305.bmp
# 1 person, Done. (12.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame306.bmp
# 1 person, Done. (11.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame307.bmp
# 1 person, Done. (11.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame308.bmp
# 1 person, Done. (11.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame309.bmp
# 2 persons, Done. (11.8ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame31.bmp
# 1 person, Done. (11.8ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame310.bmp
# 1 person, Done. (12.4ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame311.bmp
# 1 person, Done. (11.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame312.bmp
# 1 person, Done. (11.9ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame313.bmp
# 1 person, Done. (11.0ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame314.bmp
# 1 person, Done. (11.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame315.bmp
# 1 person, Done. (11.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame316.bmp
# 1 person, Done. (10.9ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame317.bmp
# 1 person, Done. (14.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame318.bmp
# 1 person, Done. (13.2ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame319.bmp
# 2 persons, Done. (11.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame32.bmp
# 1 person, Done. (18.7ms) Inference, (1.3ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame320.bmp
# 1 person, Done. (11.4ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame321.bmp
# 1 person, Done. (11.6ms) Inference, (1.2ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame322.bmp
# 1 person, Done. (10.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame323.bmp
# 1 person, Done. (11.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame324.bmp
# 1 person, Done. (11.3ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame325.bmp
# 1 person, Done. (11.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame326.bmp
# 1 person, Done. (11.3ms) Inference, (1.3ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame327.bmp
# 1 person, Done. (11.9ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame328.bmp
# 1 person, Done. (11.9ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame329.bmp
# 2 persons, Done. (11.4ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame33.bmp
# 1 person, Done. (12.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame330.bmp
# 1 person, Done. (12.0ms) Inference, (1.2ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame331.bmp
# 1 person, Done. (11.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame332.bmp
# 1 person, Done. (11.7ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame333.bmp
# 1 person, Done. (13.6ms) Inference, (1.2ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame334.bmp
# 1 person, Done. (12.5ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame335.bmp
# 1 person, Done. (11.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame336.bmp
# 1 person, Done. (10.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame337.bmp
# 1 person, Done. (10.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame338.bmp
# 1 person, Done. (11.0ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame339.bmp
# 2 persons, Done. (10.8ms) Inference, (1.2ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame34.bmp
# 1 person, Done. (13.3ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame340.bmp
# 1 person, Done. (11.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame341.bmp
# 1 person, Done. (11.1ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame342.bmp
# 2 persons, Done. (11.0ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame343.bmp
# 2 persons, Done. (11.0ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame344.bmp
# 2 persons, Done. (10.9ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame345.bmp
# 2 persons, Done. (11.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame346.bmp
# 2 persons, Done. (11.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame347.bmp
# 2 persons, Done. (11.0ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame348.bmp
# 2 persons, Done. (10.9ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame349.bmp
# 2 persons, Done. (11.4ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame35.bmp
# 2 persons, Done. (11.0ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame350.bmp
# 2 persons, Done. (11.5ms) Inference, (1.3ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame351.bmp
# 2 persons, Done. (11.4ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame352.bmp
# 2 persons, Done. (11.1ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame353.bmp
# 2 persons, Done. (12.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame354.bmp
# 2 persons, Done. (11.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame355.bmp
# 2 persons, Done. (11.9ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame356.bmp
# 2 persons, Done. (12.1ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame357.bmp
# 2 persons, Done. (12.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame358.bmp
# 2 persons, Done. (12.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame359.bmp
# 2 persons, Done. (12.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame36.bmp
# 2 persons, Done. (14.8ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame360.bmp
# 2 persons, Done. (12.0ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame361.bmp
# 2 persons, Done. (12.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame362.bmp
# 2 persons, Done. (12.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame363.bmp
# 2 persons, Done. (12.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame364.bmp
# 2 persons, Done. (12.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame365.bmp
# 2 persons, Done. (12.4ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame366.bmp
# 2 persons, Done. (12.3ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame367.bmp
# 2 persons, Done. (14.7ms) Inference, (1.3ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame368.bmp
# 2 persons, Done. (11.8ms) Inference, (1.5ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame369.bmp
# 2 persons, Done. (11.6ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame37.bmp
# 2 persons, Done. (11.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame370.bmp
# 2 persons, Done. (11.0ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame371.bmp
# 2 persons, Done. (11.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame372.bmp
# 2 persons, Done. (11.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame373.bmp
# 2 persons, Done. (11.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame374.bmp
# 2 persons, Done. (12.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame375.bmp
# 2 persons, Done. (11.0ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame376.bmp
# 2 persons, Done. (15.1ms) Inference, (1.6ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame377.bmp
# 2 persons, Done. (16.4ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame378.bmp
# 2 persons, Done. (13.4ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame379.bmp
# 2 persons, Done. (13.0ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame38.bmp
# 2 persons, Done. (12.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame380.bmp
# 2 persons, Done. (13.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame381.bmp
# 2 persons, Done. (12.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame382.bmp
# 2 persons, Done. (11.6ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame383.bmp
# 2 persons, Done. (13.3ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame384.bmp
# 2 persons, Done. (11.8ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame385.bmp
# 2 persons, Done. (11.8ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame386.bmp
# 2 persons, Done. (11.9ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame387.bmp
# 2 persons, Done. (12.0ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame388.bmp
# 2 persons, Done. (10.7ms) Inference, (1.4ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame389.bmp
# 2 persons, Done. (12.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame39.bmp
# 2 persons, Done. (12.4ms) Inference, (1.4ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame390.bmp
# 2 persons, Done. (19.8ms) Inference, (1.7ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame391.bmp
# 2 persons, Done. (18.4ms) Inference, (1.6ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame392.bmp
# 2 persons, Done. (18.8ms) Inference, (1.4ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame393.bmp
# 2 persons, Done. (20.5ms) Inference, (1.7ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame394.bmp
# 2 persons, Done. (19.4ms) Inference, (1.7ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame395.bmp
# 2 persons, Done. (12.6ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame396.bmp
# 2 persons, Done. (17.3ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame397.bmp
# 2 persons, Done. (12.3ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame398.bmp
# 2 persons, Done. (12.2ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame399.bmp
# 2 persons, Done. (12.4ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame4.bmp
# 2 persons, Done. (11.9ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame40.bmp
# 2 persons, Done. (12.8ms) Inference, (1.2ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame400.bmp
# 2 persons, Done. (12.3ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame401.bmp
# 2 persons, Done. (12.3ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame402.bmp
# 2 persons, Done. (12.2ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame403.bmp
# 2 persons, Done. (12.3ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame404.bmp
# 2 persons, Done. (12.3ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame405.bmp
# 2 persons, Done. (17.8ms) Inference, (1.3ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame406.bmp
# 2 persons, Done. (12.4ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame407.bmp
# 2 persons, Done. (12.0ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame408.bmp
# 2 persons, Done. (12.0ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame409.bmp
# 2 persons, Done. (12.3ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame41.bmp
# 2 persons, Done. (12.5ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame410.bmp
# 2 persons, Done. (12.5ms) Inference, (1.4ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame411.bmp
# 2 persons, Done. (12.1ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame412.bmp
# 2 persons, Done. (12.6ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame413.bmp
# 2 persons, Done. (13.3ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame414.bmp
# 2 persons, Done. (12.3ms) Inference, (1.3ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame415.bmp
# 2 persons, Done. (12.7ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame416.bmp
# 2 persons, Done. (12.4ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame417.bmp
# 2 persons, Done. (12.1ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame418.bmp
# 2 persons, Done. (12.1ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame419.bmp
# 2 persons, Done. (12.1ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame42.bmp
# 2 persons, Done. (17.0ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame420.bmp
# 2 persons, Done. (12.1ms) Inference, (1.1ms) NMS
# ...
# 2 persons, Done. (11.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame891.bmp
# 2 persons, Done. (11.7ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame892.bmp
# 2 persons, Done. (11.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame893.bmp
# 2 persons, Done. (12.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame894.bmp
# 2 persons, Done. (11.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame895.bmp
# 2 persons, Done. (11.5ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame896.bmp
# 2 persons, Done. (11.0ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame897.bmp
# 2 persons, Done. (11.3ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame898.bmp
# 2 persons, Done. (12.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame899.bmp
# 2 persons, Done. (11.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame9.bmp
# 2 persons, Done. (15.9ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame90.bmp
# 2 persons, Done. (11.0ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame900.bmp
# 2 persons, Done. (11.8ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame901.bmp
# 2 persons, Done. (12.0ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame902.bmp
# 2 persons, Done. (12.0ms) Inference, (1.3ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame903.bmp
# 2 persons, Done. (12.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame904.bmp
# 2 persons, Done. (11.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame905.bmp
# 2 persons, Done. (11.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame906.bmp
# 2 persons, Done. (11.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame907.bmp
# 2 persons, Done. (11.4ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame908.bmp
# 2 persons, Done. (11.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame909.bmp
# 2 persons, Done. (12.0ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame91.bmp
# 2 persons, Done. (12.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame910.bmp
# 2 persons, Done. (11.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame911.bmp
# 2 persons, Done. (11.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame912.bmp
# 2 persons, Done. (11.9ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame913.bmp
# 2 persons, Done. (12.4ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame914.bmp
# 2 persons, Done. (11.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame915.bmp
# 2 persons, Done. (15.7ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame916.bmp
# 2 persons, Done. (11.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame917.bmp
# 2 persons, Done. (14.0ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame918.bmp
# 2 persons, Done. (10.8ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame919.bmp
# 2 persons, Done. (11.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame92.bmp
# 2 persons, Done. (11.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame920.bmp
# 2 persons, Done. (11.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame921.bmp
# 2 persons, Done. (11.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame922.bmp
# 2 persons, Done. (11.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame923.bmp
# 2 persons, Done. (11.4ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame924.bmp
# 2 persons, Done. (11.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame925.bmp
# 2 persons, Done. (11.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame926.bmp
# 2 persons, Done. (12.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame927.bmp
# 2 persons, Done. (11.3ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame928.bmp
# 2 persons, Done. (11.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame929.bmp
# 2 persons, Done. (11.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame93.bmp
# 2 persons, Done. (12.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame930.bmp
# 2 persons, Done. (12.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame931.bmp
# 2 persons, Done. (15.4ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame932.bmp
# 2 persons, Done. (11.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame933.bmp
# 2 persons, Done. (11.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame934.bmp
# 2 persons, Done. (11.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame935.bmp
# 2 persons, Done. (18.1ms) Inference, (1.2ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame936.bmp
# 2 persons, Done. (12.1ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame937.bmp
# 2 persons, Done. (11.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame938.bmp
# 2 persons, Done. (11.8ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame939.bmp
# 2 persons, Done. (17.7ms) Inference, (1.4ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame94.bmp
# 2 persons, Done. (18.4ms) Inference, (1.4ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame940.bmp
# 2 persons, Done. (19.2ms) Inference, (1.4ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame941.bmp
# 2 persons, Done. (23.0ms) Inference, (3.6ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame942.bmp
# 3 persons, Done. (21.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame943.bmp
# 2 persons, Done. (11.8ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame944.bmp
# 2 persons, Done. (14.5ms) Inference, (1.2ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame945.bmp
# 3 persons, Done. (11.0ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame946.bmp
# 2 persons, Done. (13.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame947.bmp
# 2 persons, Done. (11.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame948.bmp
# 2 persons, Done. (11.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame949.bmp
# 2 persons, Done. (11.9ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame95.bmp
# 2 persons, Done. (11.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame950.bmp
# 2 persons, Done. (11.0ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame951.bmp
# 2 persons, Done. (11.5ms) Inference, (1.2ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame952.bmp
# 2 persons, Done. (11.4ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame953.bmp
# 2 persons, Done. (11.9ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame954.bmp
# 2 persons, Done. (11.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame955.bmp
# 3 persons, Done. (13.9ms) Inference, (1.2ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame956.bmp
# 2 persons, Done. (11.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame957.bmp
# 2 persons, Done. (11.2ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame958.bmp
# 2 persons, Done. (12.3ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame959.bmp
# 2 persons, Done. (11.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame96.bmp
# 2 persons, Done. (11.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame960.bmp
# 2 persons, Done. (11.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame961.bmp
# 2 persons, Done. (11.0ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame962.bmp
# 2 persons, Done. (11.7ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame963.bmp
# 2 persons, Done. (11.1ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame964.bmp
# 2 persons, Done. (14.2ms) Inference, (1.2ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame965.bmp
# 2 persons, Done. (11.9ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame966.bmp
# 2 persons, Done. (11.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame967.bmp
# 2 persons, Done. (11.9ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame968.bmp
# 2 persons, Done. (11.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame969.bmp
# 2 persons, Done. (11.0ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame97.bmp
# 2 persons, Done. (11.8ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame970.bmp
# 3 persons, Done. (11.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame971.bmp
# 2 persons, Done. (16.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame972.bmp
# 3 persons, Done. (12.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame973.bmp
# 2 persons, Done. (11.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame974.bmp
# 2 persons, Done. (11.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame975.bmp
# 3 persons, Done. (12.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame976.bmp
# 2 persons, Done. (12.4ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame977.bmp
# 2 persons, Done. (11.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame978.bmp
# 2 persons, Done. (11.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame979.bmp
# 2 persons, Done. (11.7ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame98.bmp
# 2 persons, Done. (12.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame980.bmp
# 2 persons, Done. (11.3ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame981.bmp
# 2 persons, Done. (11.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame982.bmp
# 2 persons, Done. (11.0ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame983.bmp
# 2 persons, Done. (11.1ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame984.bmp
# 2 persons, Done. (13.8ms) Inference, (1.2ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame985.bmp
# 2 persons, Done. (12.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame986.bmp
# 2 persons, Done. (17.7ms) Inference, (1.4ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame987.bmp
# 2 persons, Done. (17.4ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame988.bmp
# 2 persons, Done. (12.0ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame989.bmp
# 2 persons, Done. (11.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame99.bmp
# 2 persons, Done. (13.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame990.bmp
# 2 persons, Done. (12.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame991.bmp
# 2 persons, Done. (11.3ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame992.bmp
# 2 persons, Done. (12.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame993.bmp
# 2 persons, Done. (10.9ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame994.bmp
# 2 persons, Done. (10.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame995.bmp
# 2 persons, Done. (11.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame996.bmp
# 2 persons, Done. (13.6ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame997.bmp
# 2 persons, Done. (10.8ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame998.bmp
# 2 persons, Done. (11.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: ../datas/humans_bbox/test_1/frame999.bmp
# Done. (17.866s)
# flow4. make mask2 images
# Namespace(filename='test_1', show_viz=None)
# 100% 1001/1001 [00:02<00:00, 363.89it/s]
# flow5. detect ball
# Namespace(filename='test_1', show_viz=None)
# 100% 1001/1001 [00:10<00:00, 94.44it/s]
# flow6. convert balldet images to movie
# Namespace(filename='test_1', original_fps=30, show_viz=None, slow_rate=4.0)
# 100% 1001/1001 [00:01<00:00, 540.16it/s]

# %%
if is_save:
    from google.colab import files
    files.download(f"datas/balldet_movies/{filename}.mp4")
